# %%
import pandas as pd
import ast

dfc = pd.read_csv("../data/raw/tmdb_6000/tmdb_6000_movie_credits.csv")

# Drop useless index column
dfc = dfc.drop(columns=["Unnamed: 0"])

dfc.head(2)
# Out:
#    tmdbId                                               cast  \
# 0   19995  [{"cast_id": 242, "character": "Jake Sully", "...
# 1     285  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...

# %%
def to_list_of_dicts(x):
    if pd.isna(x):
        return []
    try:
        data = ast.literal_eval(x)
        if isinstance(data, list):
            return [d for d in data if isinstance(d, dict)]
    except:
        pass
    return []

dfc["cast_list"] = dfc["cast"].apply(to_list_of_dicts)
dfc["crew_list"] = dfc["crew"].apply(to_list_of_dicts)

# %%
dfc[["cast_list", "crew_list"]].loc[0]
# Out:
# cast_list    [{'cast_id': 242, 'character': 'Jake Sully', '...
# crew_list    [{'credit_id': '52fe48009251416c750aca23', 'de...
# Name: 0, dtype: object

# %%
def extract_top_cast(cast_list, n=5):
    """
    Function to extract top cast members
    """
    if not isinstance(cast_list, list):
        return []
        
    # Sort by "order" if it exists, otherwise fallback
    try:
        sorted_cast = sorted(cast_list, key=lambda d: d.get("order", 9999))
    except:
        sorted_cast = cast_list

    names = [d.get("name") for d in sorted_cast if "name" in d]
    return names[:n]

dfc["top_cast"] = dfc["cast_list"].apply(extract_top_cast)

dfc[["tmdbId", "top_cast"]].head(5)
# Out:
#    tmdbId                                           top_cast
# 0   19995  [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 1     285  [Johnny Depp, Orlando Bloom, Keira Knightley, ...
# 2  206647  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...
# 3   49026  [Christian Bale, Michael Caine, Gary Oldman, A...
# 4   49529  [Taylor Kitsch, Lynn Collins, Samantha Morton,...

# %%
def extract_by_job(crew_list, jobs):
    results = []
    for d in crew_list:
        job = d.get("job", "").lower()
        name = d.get("name", "")
        if not name:
            continue
        for j in jobs:
            if job == j.lower():
                results.append(name)
    # remove duplicates while keeping order
    return list(dict.fromkeys(results))

# %%
dfc["directors"] = dfc["crew_list"].apply(lambda c: extract_by_job(c, ["Director"]))
dfc["writers"]   = dfc["crew_list"].apply(lambda c: extract_by_job(c, ["Writer", "Screenplay", "Screenplay By", "Author", "Story"]))
dfc["producers"] = dfc["crew_list"].apply(lambda c: extract_by_job(c, ["Producer"]))

# %%
dfc[["tmdbId", "directors", "writers"]].head(10)
dfc.head()
# Out:
#    tmdbId                                               cast  \
# 0   19995  [{"cast_id": 242, "character": "Jake Sully", "...
# 1     285  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  206647  [{"cast_id": 1, "character": "James Bond", "cr...
# 3   49026  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4   49529  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
#                                            cast_list  \
# 0  [{'cast_id': 242, 'character': 'Jake Sully', '...
# 1  [{'cast_id': 4, 'character': 'Captain Jack Spa...
# 2  [{'cast_id': 1, 'character': 'James Bond', 'cr...
# 3  [{'cast_id': 2, 'character': 'Bruce Wayne / Ba...
# 4  [{'cast_id': 5, 'character': 'John Carter', 'c...
#
#                                            crew_list  \
# 0  [{'credit_id': '52fe48009251416c750aca23', 'de...
# 1  [{'credit_id': '52fe4232c3a36847f800b579', 'de...
# 2  [{'credit_id': '54805967c3a36829b5002c41', 'de...
# 3  [{'credit_id': '52fe4781c3a36847f81398c3', 'de...
# 4  [{'credit_id': '52fe479ac3a36847f813eaa3', 'de...
#
#                                             top_cast            directors  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...      [James Cameron]
# 1  [Johnny Depp, Orlando Bloom, Keira Knightley, ...     [Gore Verbinski]
# 2  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...         [Sam Mendes]
# 3  [Christian Bale, Michael Caine, Gary Oldman, A...  [Christopher Nolan]
# 4  [Taylor Kitsch, Lynn Collins, Samantha Morton,...     [Andrew Stanton]
#
#                                              writers  \
# 0                                    [James Cameron]
# 1                        [Ted Elliott, Terry Rossio]
# 2  [John Logan, Robert Wade, Neal Purvis, Jez But...
# 3  [Christopher Nolan, Jonathan Nolan, David S. G...
# 4     [Andrew Stanton, Michael Chabon, Mark Andrews]
#
#                                            producers
# 0                        [James Cameron, Jon Landau]
# 1  [Jerry Bruckheimer, Eric McLeod, Chad Oman, Pe...
# 2              [Barbara Broccoli, Michael G. Wilson]
# 3    [Charles Roven, Christopher Nolan, Emma Thomas]
# 4        [Colin Wilson, Jim Morris, Lindsey Collins]

# %%
for col in ["top_cast", "directors", "writers", "producers"]:
    dfc[col + "_str"] = dfc[col].apply(lambda x: ", ".join(x) if isinstance(x, list) else "")

# %%
dfc.columns
# Out:
# Index(['tmdbId', 'cast', 'crew', 'cast_list', 'crew_list', 'top_cast',
#        'directors', 'writers', 'producers', 'top_cast_str', 'directors_str',
#        'writers_str', 'producers_str'],
#       dtype='object')

# %%
dfc
# Out:
#        tmdbId                                               cast  \
# 0       19995  [{"cast_id": 242, "character": "Jake Sully", "...
# 1         285  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2      206647  [{"cast_id": 1, "character": "James Bond", "cr...
# 3       49026  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4       49529  [{"cast_id": 5, "character": "John Carter", "c...
# ...       ...                                                ...
# 5793   626332  [{'adult': False, 'gender': 2, 'id': 66525, 'k...
# 5794  1094319  [{'adult': False, 'gender': 2, 'id': 72440, 'k...
# 5795   998623  [{'adult': False, 'gender': 0, 'id': 2791253, ...
# 5796  1155770  [{'adult': False, 'gender': 2, 'id': 20422, 'k...
# 5797   842544  [{'adult': False, 'gender': 2, 'id': 65731, 'k...
#
#                                                    crew  \
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2     [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
# ...                                                 ...
# 5793  [{'adult': False, 'gender': 2, 'id': 52035, 'k...
# 5794  [{'adult': False, 'gender': 2, 'id': 59502, 'k...
# 5795  [{'adult': False, 'gender': 2, 'id': 216023, '...
# 5796  [{'adult': False, 'gender': 2, 'id': 1551, 'kn...
# 5797  [{'adult': False, 'gender': 2, 'id': 65731, 'k...
#
#                                               cast_list  \
# 0     [{'cast_id': 242, 'character': 'Jake Sully', '...
# 1     [{'cast_id': 4, 'character': 'Captain Jack Spa...
# 2     [{'cast_id': 1, 'character': 'James Bond', 'cr...
# 3     [{'cast_id': 2, 'character': 'Bruce Wayne / Ba...
# 4     [{'cast_id': 5, 'character': 'John Carter', 'c...
# ...                                                 ...
# 5793  [{'adult': False, 'gender': 2, 'id': 66525, 'k...
# 5794  [{'adult': False, 'gender': 2, 'id': 72440, 'k...
# 5795  [{'adult': False, 'gender': 0, 'id': 2791253, ...
# 5796  [{'adult': False, 'gender': 2, 'id': 20422, 'k...
# 5797  [{'adult': False, 'gender': 2, 'id': 65731, 'k...
#
#                                               crew_list  \
# 0     [{'credit_id': '52fe48009251416c750aca23', 'de...
# 1     [{'credit_id': '52fe4232c3a36847f800b579', 'de...
# 2     [{'credit_id': '54805967c3a36829b5002c41', 'de...
# 3     [{'credit_id': '52fe4781c3a36847f81398c3', 'de...
# 4     [{'credit_id': '52fe479ac3a36847f813eaa3', 'de...
# ...                                                 ...
# 5793  [{'adult': False, 'gender': 2, 'id': 52035, 'k...
# 5794  [{'adult': False, 'gender': 2, 'id': 59502, 'k...
# 5795  [{'adult': False, 'gender': 2, 'id': 216023, '...
# 5796  [{'adult': False, 'gender': 2, 'id': 1551, 'kn...
# 5797  [{'adult': False, 'gender': 2, 'id': 65731, 'k...
#
#                                                top_cast            directors  \
# 0     [Sam Worthington, Zoe Saldana, Sigourney Weave...      [James Cameron]
# 1     [Johnny Depp, Orlando Bloom, Keira Knightley, ...     [Gore Verbinski]
# 2     [Daniel Craig, Christoph Waltz, Léa Seydoux, R...         [Sam Mendes]
# 3     [Christian Bale, Michael Caine, Gary Oldman, A...  [Christopher Nolan]
# 4     [Taylor Kitsch, Lynn Collins, Samantha Morton,...     [Andrew Stanton]
# ...                                                 ...                  ...
# 5793  [Jesse Garcia, Annie Gonzalez, Emilio Rivera, ...       [Eva Longoria]
# 5794  [Brendan Fehr, Dolph Lundgren, Luke Wilson, Ni...   [Shane Dax Taylor]
# 5795  [Orlando Vauthier, Axel Granberger, Camille Lé...      [Olivier Abbou]
# 5796  [John le Carré, Jake Dove, Charlotte Hamblin, ...       [Errol Morris]
# 5797  [Sam Worthington, Matt Nable, Phoebe Tonkin, E...         [Matt Nable]
#
#                                                 writers  \
# 0                                       [James Cameron]
# 1                           [Ted Elliott, Terry Rossio]
# 2     [John Logan, Robert Wade, Neal Purvis, Jez But...
# 3     [Christopher Nolan, Jonathan Nolan, David S. G...
# 4        [Andrew Stanton, Michael Chabon, Mark Andrews]
# ...                                                 ...
# 5793                [Lewis Colick, Linda Yvette Chavez]
# 5794  [Shane Dax Taylor, Daniel Zirilli, C. Alec Ros...
# 5795  [Olivier Abbou, Thibault Lang-Willar, Mathilde...
# 5796                                     [Errol Morris]
# 5797                                       [Matt Nable]
#
#                                               producers  \
# 0                           [James Cameron, Jon Landau]
# 1     [Jerry Bruckheimer, Eric McLeod, Chad Oman, Pe...
# 2                 [Barbara Broccoli, Michael G. Wilson]
# 3       [Charles Roven, Christopher Nolan, Emma Thomas]
# 4           [Colin Wilson, Jim Morris, Lindsey Collins]
# ...                                                 ...
# 5793                                   [DeVon Franklin]
# 5794                                                 []
# 5795  [Bruno Merle, Olivier Abbou, Noor "Rize" Sadar...
# 5796  [Errol Morris, Stephen Cornwell, Dominic Cross...
# 5797                    [Michael Schwarz, John Schwarz]
#
#                                            top_cast_str      directors_str  \
# 0     Sam Worthington, Zoe Saldana, Sigourney Weaver...      James Cameron
# 1     Johnny Depp, Orlando Bloom, Keira Knightley, S...     Gore Verbinski
# 2     Daniel Craig, Christoph Waltz, Léa Seydoux, Ra...         Sam Mendes
# 3     Christian Bale, Michael Caine, Gary Oldman, An...  Christopher Nolan
# 4     Taylor Kitsch, Lynn Collins, Samantha Morton, ...     Andrew Stanton
# ...                                                 ...                ...
# 5793  Jesse Garcia, Annie Gonzalez, Emilio Rivera, V...       Eva Longoria
# 5794  Brendan Fehr, Dolph Lundgren, Luke Wilson, Nic...   Shane Dax Taylor
# 5795  Orlando Vauthier, Axel Granberger, Camille Léo...      Olivier Abbou
# 5796  John le Carré, Jake Dove, Charlotte Hamblin, G...       Errol Morris
# 5797  Sam Worthington, Matt Nable, Phoebe Tonkin, Ed...         Matt Nable
#
#                                             writers_str  \
# 0                                         James Cameron
# 1                             Ted Elliott, Terry Rossio
# 2     John Logan, Robert Wade, Neal Purvis, Jez Butt...
# 3     Christopher Nolan, Jonathan Nolan, David S. Goyer
# 4          Andrew Stanton, Michael Chabon, Mark Andrews
# ...                                                 ...
# 5793                  Lewis Colick, Linda Yvette Chavez
# 5794   Shane Dax Taylor, Daniel Zirilli, C. Alec Rossel
# 5795  Olivier Abbou, Thibault Lang-Willar, Mathilde ...
# 5796                                       Errol Morris
# 5797                                         Matt Nable
#
#                                           producers_str
# 0                             James Cameron, Jon Landau
# 1     Jerry Bruckheimer, Eric McLeod, Chad Oman, Pet...
# 2                   Barbara Broccoli, Michael G. Wilson
# 3         Charles Roven, Christopher Nolan, Emma Thomas
# 4             Colin Wilson, Jim Morris, Lindsey Collins
# ...                                                 ...
# 5793                                     DeVon Franklin
# 5794
# 5795  Bruno Merle, Olivier Abbou, Noor "Rize" Sadar,...
# 5796  Errol Morris, Stephen Cornwell, Dominic Crossl...
# 5797                      Michael Schwarz, John Schwarz
#
# [5798 rows x 13 columns]

# %%
# Replace list columns with the clean string columns

final_df = pd.DataFrame({
    "tmdbId": dfc["tmdbId"],
    "top_cast": dfc["top_cast_str"],
    "directors": dfc["directors_str"],
    "writers": dfc["writers_str"],
    "producers": dfc["producers_str"]
})

# %%
final_df.head()
# Out:
#    tmdbId                                           top_cast  \
# 0   19995  Sam Worthington, Zoe Saldana, Sigourney Weaver...
# 1     285  Johnny Depp, Orlando Bloom, Keira Knightley, S...
# 2  206647  Daniel Craig, Christoph Waltz, Léa Seydoux, Ra...
# 3   49026  Christian Bale, Michael Caine, Gary Oldman, An...
# 4   49529  Taylor Kitsch, Lynn Collins, Samantha Morton, ...
#
#            directors                                            writers  \
# 0      James Cameron                                      James Cameron
# 1     Gore Verbinski                          Ted Elliott, Terry Rossio
# 2         Sam Mendes  John Logan, Robert Wade, Neal Purvis, Jez Butt...
# 3  Christopher Nolan  Christopher Nolan, Jonathan Nolan, David S. Goyer
# 4     Andrew Stanton       Andrew Stanton, Michael Chabon, Mark Andrews
#
#                                            producers
# 0                          James Cameron, Jon Landau
# 1  Jerry Bruckheimer, Eric McLeod, Chad Oman, Pet...
# 2                Barbara Broccoli, Michael G. Wilson
# 3      Charles Roven, Christopher Nolan, Emma Thomas
# 4          Colin Wilson, Jim Morris, Lindsey Collins

# %%
# Save the final clean credits dataset
final_df.to_csv("../data/processed/credits_clean.csv", index=False)

# %%
final_df.size
# Out:
# 28990
